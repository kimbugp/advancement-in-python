# %% [markdown]
# #### Lambda and list comprehision
#
# What is faster

# %%
import time
import calendar
import pandas as pd
methods = {
    "lambda":
    lambda start, stop: filter(lambda x: calendar.isleap(x),
                               range(start, stop, +1)),
    "comprehesion":
    lambda start, stop:
    [x for x in range(start, stop, +1) if calendar.isleap(x)]
}


def get_leap_years(start: int, stop: int, method):
    if start > stop:
        start, stop = stop, start
    leap_years = method(start, stop)
    return list(leap_years)


x = pd.DataFrame(None, columns=methods.keys())
for _ in range(1000):
    y = {}
    for key, method in methods.items():
        start = time.time()
        get_leap_years(1, 2100, method)
        end = time.time()
        y[key] = end - start
    x = x.append(y, True)

print(x.mean())
# Out:
# lambda          0.000566
# comprehesion    0.000475
# dtype: float64

# %%
x
# Out:
# Empty DataFrame
# Columns: [lambda, comprehesion]
# Index: []

# %%
x
# Out:
#        lambda  comprehesion
# 0    0.000699      0.000769
# 1    0.000909      0.000588
# 2    0.000926      0.001512
# 3    0.001132      0.000868
# 4    0.000830      0.000504
# 5    0.000548      0.000428
# 6    0.000648      0.000536
# 7    0.000914      0.000507
# 8    0.000627      0.000548
# 9    0.000472      0.000435
# 10   0.000728      0.000620
# 11   0.000466      0.000371
# 12   0.000678      0.000794
# 13   0.000592      0.000503
# 14   0.000540      0.000562
# 15   0.000685      0.000425
# 16   0.000673      0.000515
# 17   0.000496      0.000379
# 18   0.000530      0.000375
# 19   0.000704      0.000374
# 20   0.000507      0.000413
# 21   0.000479      0.000372
# 22   0.000467      0.000375
# 23   0.000463      0.000410
# 24   0.001211      0.000469
# 25   0.000464      0.000447
# 26   0.000466      0.000375
# 27   0.000460      0.000599
# 28   0.000462      0.000371
# 29   0.000466      0.000432
# ..        ...           ...
# 970  0.000468      0.000416
# 971  0.000460      0.000373
# 972  0.000457      0.000420
# 973  0.000536      0.000456
# 974  0.000481      0.000373
# 975  0.000465      0.000374
# 976  0.000486      0.000445
# 977  0.000459      0.000372
# 978  0.000457      0.000373
# 979  0.000466      0.000372
# 980  0.000462      0.000372
# 981  0.000529      0.000376
# 982  0.000636      0.000458
# 983  0.000771      0.000569
# 984  0.000459      0.000374
# 985  0.000466      0.000370
# 986  0.000462      0.000374
# 987  0.000460      0.000373
# 988  0.000456      0.000372
# 989  0.000459      0.000421
# 990  0.000456      0.001081
# 991  0.000835      0.000592
# 992  0.000592      0.000546
# 993  0.000613      0.000538
# 994  0.000458      0.000372
# 995  0.000468      0.000377
# 996  0.000462      0.000374
# 997  0.000488      0.000505
# 998  0.001223      0.000768
# 999  0.000531      0.000662
#
# [1000 rows x 2 columns]
